# %% [markdown]
# ## 탐색적 데이터 분석(EDA, exploratory Data analysis)
# - 데이터의 주요 특성을 파악하고, 패턴을 찾고, 이상값을 식별하며, 가설을 세위기 위한 방법론
# - 데이터 분석 초기 단계에 수행되며, 데이터를 시각화하고 통계적으로 요약
#
# 1. 데이터의 분포와 패턴 파악
# 2. 이상값탐지
# 3. 변수 간 관계 확인
# 4. 데이터의 통계적 요약

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\202-15\anaconda3\envs\tech9\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

train = pd.read_csv("../dataset/titanic/train.csv", index_col='PassengerId')
train.shape
# Out:
# (891, 11)

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# - survived : 생존 1, 사망 0
# - pclass : 1,2,3등석
# - sibsp : siblings/spouses(형제, 배우자)
# - parch : parents/children(부모님, 자녀)
# - cabin : 선실 번호
# - embarked : 선착장

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# ## 척도
# ### 질적 척도
# - 명목척도 : 관찰하는 대상의 속성에 따라 그 값을 숫자로 나타냄, 분류할 목적으로 숫자를 사용하고
#               숫자 자체가 가지고 있는 의미는 없음(남자 -> 1, 여자 -> 0)
# - 서열척도 : 관찰하는 대상의 특성을 축정해서 그 값을 순위로 나타내는 것(1등, 2등...) 높낮이는 알 수 있지만
#               어느정도 차이인지는 알 수 없음.
# ### 양적 척도
# - 등간척도 : 관찰하는 대상의 속성을 상대적 크기로 나타냄 순위를 부여 할 뿐만 아니라 어느 정도 큰지 숫자간의
#               의미가 있음(온도, 날짜) 가산이 가능함.
# - 비율척도 : 절대적 기준이 있는 영점이 존재하고 모든 사칙연산이 가능함(판매량, 점수, 키,..)

# %%
train.isnull().sum() # 결측치 체크
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
gender_mean = train.groupby('Sex')['Age'].mean()
gender_mean
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
# 결측치는 평균값, 중앙값, 선행값, 후행값, 그룹 평균값등 다양한 값으로 대처할 수 있음
# 남자, 여자 각각 평균으로 대체
train.loc[(train['Sex'] == 'female') & (train['Age'].isnull()),'Age'] = int(gender_mean[0])
train.loc[(train['Sex'] == 'male') & (train['Age'].isnull()),'Age'] = int(gender_mean[1])
train.isunll().sum()
# Out:
# C:\Users\202-15\AppData\Local\Temp\ipykernel_14116\244177506.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   train.loc[(train['Sex'] == 'female') & (train['Age'].isnull()),'Age'] = int(gender_mean[0])
# C:\Users\202-15\AppData\Local\Temp\ipykernel_14116\244177506.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   train.loc[(train['Sex'] == 'male') & (train['Age'].isnull()),'Age'] = int(gender_mean[1])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       3 train.loc[(train['Sex'] == 'female') & (train['Age'].isnull()),'Age'] = int(gender_mean[0])
#       4 train.loc[(train['Sex'] == 'male') & (train['Age'].isnull()),'Age'] = int(gender_mean[1])
# ----> 5 train.isunll().sum()
#
# File ~\anaconda3\envs\tech9\lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isunll'

# %%
train.Cabin.value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
train['Cabin'] = train['Cabin'].fillna('N') # null값 N으로

# %%
train = train.dropna() # 결측값 포함된 행 제거
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
### 생존자, 사망자 인원수 출력
train['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    340
# Name: count, dtype: int64

# %%
# 라벨 칼럼생성
train['Survived_label'] = train['Survived'].replace(0,'Dead').replace(1,'Survived')
train['Survived_label'].value_counts()
# Out:
# C:\Users\202-15\AppData\Local\Temp\ipykernel_14116\1001829725.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Survived_label'] = train['Survived'].replace(0,'Dead').replace(1,'Survived')
# Survived_label
# Dead        549
# Survived    340
# Name: count, dtype: int64

# %%
train['Survived_label'].value_counts().plot(kind='bar', rot='vertical')
# Out:
# <Axes: xlabel='Survived_label'>

# %%
# 객실 시각화
train['Pclass_label'] = train['Pclass'].replace(1, 'First').replace(2,'Business').replace(3,'Economy')
train['Pclass_label'].value_counts().plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data=train, x="Pclass_label",hue="Survived_label")
# Out:
# <Axes: xlabel='Pclass_label', ylabel='count'>

# %%
# 성별 생존 여부
sns.countplot(data=train, x='Sex',hue="Survived_label")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# 나이별 생존 여부
f = sns.FacetGrid(train,hue='Survived_label',aspect=3)
f.map(sns.kdeplot,'Age',fill=True)
f.set(xlim=(0,train['Age'].max()))
f.add_legend()

# %%
# 형제, 배우자
sns.countplot(data=train,x='SibSp',hue='Survived_label')
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
# 부모, 자식
sns.countplot(data=train,x='Parch',hue='Survived_label')
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
# 가족 유무
train.loc[(train['SibSp'] == 0) & (train['Parch'] == 0), 'Single'] = 'Single'
train.loc[(train['SibSp'] != 0) & (train['Parch'] != 0), 'Single'] = 'Family'
sns.countplot(data=train,x='Single',hue='Survived_label')
# Out:
# <Axes: xlabel='Single', ylabel='count'>
